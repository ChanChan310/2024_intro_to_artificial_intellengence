# %%
# !pip install jupyter_http_over_ws

# %%
# cell 1
# Mount your google drive and make a directory for this task. You don't need to modify the code in this cell!
# from google.colab import drive
import os
# drive.mount('/content/drive', force_remount=True)
if not os.path.exists("/notebooks/nerfstudio"):
  os.mkdir("/notebooks/nerfstudio")
else:
  print("nerfstudio directory exists!")
if not os.path.exists("/notebooks/nerfstudio/custom_data"):
  os.mkdir("/notebooks/nerfstudio/custom_data")
else:
  print("custom_data directory exists!")
# Out:
# nerfstudio directory exists!
# custom_data directory exists!

# %%
# cell 2
# Install Nerfstudio and Dependencies (~8 min). You don't need to modify the code in this cell!

# %cd /notebooks/
# !pip install --upgrade pip
# !pip install torch==2.0.1+cu118 torchvision==0.15.2+cu118 torchaudio==2.0.2+cu118 --extra-index-url https://download.pytorch.org/whl/cu118

# Install TinyCuda
# %cd /notebooks/
# !pip install gdown
# !gdown "https://drive.google.com/u/1/uc?id=1-7x7qQfB7bIw2zV4Lr6-yhvMpjXC84Q5&confirm=t"
# !pip install tinycudann-1.7-cp310-cp310-linux_x86_64.whl

# Install COLMAP
# %cd /notebooks/
# !apt-get install colmap -y
# !Y

# Install nerfstudio
# %cd /notebooks/
# !pip install git+https://github.com/nerfstudio-project/nerfstudio.git

# !apt-get install unzip -y
# !pip install pickleshare
# !apt install ffmpeg -y

# !apt-get upgrade -y
# Out:
# /notebooks
# /opt/venv/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 86.1 kB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 22.0.2
#     Uninstalling pip-22.0.2:
#       Successfully uninstalled pip-22.0.2
# ...
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu118
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 GB 3.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 3.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 3.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 MB 4.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 4.2 MB/s eta 0:00:00
# ...

# %%
# !nvidia-smi
# Out:
# Tue Nov  5 14:36:35 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.120                Driver Version: 550.120        CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4080 ...    Off |   00000000:01:00.0 Off |                  N/A |
# |  0%   34C    P8              8W /  320W |      59MiB /  16376MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# cell 3
# Upload the 'custom_data.zip' directory in the 'nerfstudio' directory on your Google Drive.
# Your training data should be named 'custom_data.zip'. The custom_data should include four image directories, one 'log.txt,' and one 'transform.json.'

# %cd /notebooks/nerfstudio
# !unzip custom_data.zip -d /notebooks/nerfstudio/custom_data
# Out:
# /notebooks/nerfstudio
# Archive:  custom_data.zip
#   inflating: /notebooks/nerfstudio/custom_data/images/0268.png
#   inflating: /notebooks/nerfstudio/custom_data/images/0289.png
#   inflating: /notebooks/nerfstudio/custom_data/images/0218.png
#   inflating: /notebooks/nerfstudio/custom_data/images/0126.png
#   inflating: /notebooks/nerfstudio/custom_data/images/0140.png
#   inflating: /notebooks/nerfstudio/custom_data/images/0114.png
#   inflating: /notebooks/nerfstudio/custom_data/images/0212.png
#   inflating: /notebooks/nerfstudio/custom_data/images/0016.png
#   inflating: /notebooks/nerfstudio/custom_data/images/0020.png
#   inflating: /notebooks/nerfstudio/custom_data/images/0033.png
#   inflating: /notebooks/nerfstudio/custom_data/images/0079.png
#   inflating: /notebooks/nerfstudio/custom_data/images/0040.png
#   inflating: /notebooks/nerfstudio/custom_data/images/0279.png
#   inflating: /notebooks/nerfstudio/custom_data/images/0174.png
# ...

# %%
# cell 4
# Start training (~1 hours)
# After running this cell, you should paste the command into the black window
# Open the share URL displayed in the window at another web browser, then you can edit the video

# training data in cell 3
data_path = "/notebooks/nerfstudio/custom_data"

# %cd /notebooks
# !pip install colab-xterm
# %load_ext colabxterm
# %env TERM=xterm
from IPython.display import clear_output

clear_output(wait=True)

print(
    "\033[1m"
    + "Copy and paste the following command into the terminal window that pops up under this cell."
    + "\033[0m"
)
print(
    f"ns-train nerfacto --viewer.websocket-port 7007 --viewer.make-share-url True nerfstudio-data --data {data_path}"
)
print()
# !ns-train nerfacto --viewer.websocket-port 7007 --viewer.make-share-url True nerfstudio-data --data /notebooks/nerfstudio/custom_data

# %xterm
# Out:
# Copy and paste the following command into the terminal window that pops up under this cell.
# ns-train nerfacto --viewer.websocket-port 7007 --viewer.make-share-url True nerfstudio-data --data /notebooks/nerfstudio/custom_data
# Launching Xterm...
#       <iframe id="xterm-frame-3bd6f2494355986b" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("xterm-frame-3bd6f2494355986b");
#           const url = new URL("/", window.location);
#           const port = 10000;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# cell 5
# Once your NeRF has been fully trained, nerfstudio saves a checkpoint of it automatically.
# Use this code and then customize the part '--load-config' to what’s unique to you.
# Documentation: https://docs.nerf.studio/reference/cli/ns_viewer.html
# !ns-viewer --viewer.websocket-port 7007 --viewer.make-share-url True --load-config /notebooks/outputs/unnamed/nerfacto/2024-11-05_144003/config.yml
# Out:
# /opt/venv/lib/python3.10/site-packages/tinycudann/modules.py:52: UserWarning: tinycudann was built for lower compute capability (75) than the system's (89). Performance may be suboptimal.
#   warnings.warn(f"tinycudann was built for lower compute capability ({cc}) than the system's ({system_compute_capability}). Performance may be suboptimal.")
# [17:54:01] Auto image downscale factor of 2                                                 ]8;id=14290;file:///opt/venv/lib/python3.10/site-packages/nerfstudio/data/dataparsers/nerfstudio_dataparser.py\nerfstudio_dataparser.py]8;;\:]8;id=112846;file:///opt/venv/lib/python3.10/site-packages/nerfstudio/data/dataparsers/nerfstudio_dataparser.py#484\484]8;;\
# /opt/venv/lib/python3.10/site-packages/tinycudann/modules.py:52: UserWarning: tinycudann was built for lower compute capability (75) than the system's (89). Performance may be suboptimal.
# ...

# %%
/outputs/unnamed/nerfacto/2024-11-02_133609/config.yml

# %%
# cell 6
# After execution, you can find the output directory under the nerfstudio folder, containing the captured video content.
# You can find the folder paths by checking the left sidebar.
# Here's an example command.

# %cd /notebooks/nerfstudio/
# !ns-render camera-path --load-config outputs/unnamed/nerfacto/2024-11-05_144003/config.yml --camera-path-filename /outputs/unnamed/nerfacto/2024-11-05_144003/camera_paths/2024-11-05-14-41-36.json --output-path renders/2024-11-05_144003/2024-11-05-14-41-36.mp4
# !ns-render camera-path --load-config /notebooks/nerfstudio/outputs/unnamed/nerfacto/2024-10-19_085907/config.yml --camera-path-filename /notebooks/nerfstudio/outputs/unnamed/nerfacto/2024-10-19_085907/camera_paths/2024-10-19-08-59-24.json --output-path renders/video.mp4
# Out:
# /notebooks/nerfstudio
# /usr/bin/sh: 1: sudo: not found
# /opt/venv/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
